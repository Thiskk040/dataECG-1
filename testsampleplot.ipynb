# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df   = pd.read_csv("ECG_0001_Woman.csv")
x =df["HRV_LFHF"]
y = df["time"]
print(x,y)
# Out:
# 0       0.777140
# 1       0.777140
# 2       0.777140
# 3       0.777140
# 4       0.777140
#           ...
# 1700    0.094469
# 1701    0.095004
# 1702    0.095541
# 1703    0.096079
# 1704    0.096555
# Name: HRV_LFHF, Length: 1705, dtype: float64 0         0.0
# 1         0.1
# 2         0.2
# 3         0.3
# 4         0.4
#         ...
# 1700    170.0
# 1701    170.1
# 1702    170.2
# 1703    170.3
# 1704    170.4
# Name: time, Length: 1705, dtype: float64

# %%
plt.plot(y,x)
plt.title("HRV_LFHF_0001_WomanAvatar")
plt.grid()
plt.text(140,-0.1,"Using Sampling rate 100, With reacord Baseline1 Sec",fontsize=6)
plt.xlabel("Time[Sec]")
plt.ylabel("Spectrum[HZ]")
# Out:
# Text(0, 0.5, 'Spectrum[HZ]')
